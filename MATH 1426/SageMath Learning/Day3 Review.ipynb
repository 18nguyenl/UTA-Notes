# %%
x = var('x')
plot([sin(x), cos(x)], xmin=-10, xmax=10, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(sqrt(36-x^2), x)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(integral(x*sin(x), x, 0, pi))
# Out:
# pi

# %%
show(integral(21*x*(6-x), x, 6, 2))
# Out:
# -560

# %%
show(integral(2*x + 5, x, 0, 4))
# Out:
# 36

# %%
show(integral(x^2 - 1, x, 0, 9))
# Out:
# 234

# %%
show(integral(x^2 - 9, x, 3, 8))
# Out:
# 350/3

# %%
show(integral(sin(x) + cos(x), x, -pi/4, 7*pi/4))
# Out:
# 0

# %%
show(integral(4*x^2 + 2, x, 0, 1))
# Out:
# 10/3

# %%
show(integral(2*x^2 + 3*x, x, 3, 5))
# Out:
# 268/3

# %%
show(integral(2*x + sqrt(x), x, 0, 4))
# Out:
# 64/3

# %%
show(integral(x^-3 - 23, x, 1/2, 1))
# Out:
# -10

# %%
show(integral((3-x)*(x-6), x, 3, 6))
# Out:
# 9/2

# %%
show(integral(4*sec(x)^2, x, 0, pi/4))
# Out:
# 4

# %%
show(integral(cos(x)-3, x, -pi/2, pi/2))
# Out:
# -3*pi + 2

# %%
t = var('t')
show(integral(5/t, t, 1, 3))
# Out:
# 5*log(3)

# %%
y = var('y')
show(integral(y^(1/3), y, 1, 8))
# Out:
# 45/4

# %%
show((1/2)*integral(e^x, x, 0, ln(4)))
# Out:
# 3/2

# %%
s = var('s')
show(integral((8*s^2-2)/(s^3), s, 1, 7))
# Out:
# 8*log(7) - 48/49

# %%
z = var('z')
show(integral((z^2+4)/z, z, 1, 2))
# Out:
# 4*log(2) + 3/2

# %%
show(integral(x^2 - 30, x, -2, 4))
# Out:
# -156

# %%
show(-integral(sin(x), x, -2*pi/3, 0) + integral(sin(x), x, 0, pi/3))
# Out:
# 2

# %%
show(integral(19*t^2 + t + 5, t, 2, x).diff())
# Out:
# 19*x^2 + x + 5
# integrate(sqrt(t^3 + 3), t, x, 4)

# %%
t, x = var('t', 'x')
show((((2*(5^3 + 1)^(3/2))/3)-((2*(x^3 + 1)^(3/2))/3)).diff())
show(-integrate((t^3 + 1)^(1/2), t, 4, x))
# Out:
# -3*sqrt(x^3 + 1)*x^2
# -integrate(sqrt(t^3 + 1), t, 4, x)

# %%
show(integral((4*x + 3)*sqrt(2*x^2 + 3*x), x))
show(integral(x^3*e^(x^4), x))
show(integral((3*x^3)/sqrt(1-6*x^4), x))
show(integral((sqrt(x)+1)^3/(2*sqrt(x)), x))
show(integral(x^4*(x^5 + 29)^5, x))
# Out:
# 2/3*(2*x^2 + 3*x)^(3/2)
# 1/4*e^(x^4)
# -1/4*sqrt(-6*x^4 + 1)
# 1/4*(sqrt(x) + 1)^4
# 1/30*(x^5 + 29)^6

# %%
w = var('w')
show(integral(sec(37*w)*tan(37*w), w))
show(integral(sec(2*x + 9)*tan(2*x + 9), x))
show(integral((sec(x))^2/(tan(x))^5, x))
show(integral(sin(x)*(sec(x))^7, x))
show(integral((e^(4*x))/(e^(4*x)+6), x))
show(derivative(e^(4*x), x))
show(integral(cos(3*x), x, 0, pi/2))
# Out:
# 1/37/cos(37*w)
# 1/2/cos(2*x + 9)
# -1/4/tan(x)^4
# -1/6/(sin(x)^2 - 1)^3
# 1/4*log(e^(4*x) + 6)
# 4*e^(4*x)
# -1/3

# %%
show(integral(8*e^(2*x), x, 0, 3))
show(integral((2*x)/(x^2+4)^3, x, 0, 1))
show(integral(-2*cot(x)*(csc(x))^2, x, pi/4, pi/2))
show(integral(x^2*e^(x^3-1), x, 1, 3))
p = var('p')
show(integral(p/sqrt(36+p^2), p, 0, 8))
show(integral(-sin(x)/cos(x)^2, x, -pi/4, pi/6))
show(integral(x^3*sqrt(1-x^4), x, 0, 1))
show(integral((sin(x))/(5+cos(x)), x, -pi/2, 0))
# Out:
# 4*e^6 - 4
# 9/800
# -1
# 1/3*e^26 - 1/3
# 4
# -2/3*sqrt(3) + sqrt(2)
# 1/6
# -log(6) + log(5)

# %%
show(integral(x/(x+4), x))
show(integral(x/sqrt(x-9), x))
show(integral((e^x-e^-x)/(e^x+e^-x),x))
show(integral(x*(6*x+1)^(1/3), x))
# Out:
# x - 4*log(x + 4)
# 2/3*(x - 9)^(3/2) + 18*sqrt(x - 9)
# log(e^(-x) + e^x)
# 1/84*(6*x + 1)^(7/3) - 1/48*(6*x + 1)^(4/3)

# %%
t = var('t')
v(t) =  3*t^2-36*t+105
show(solve(v, t))
show(integral(abs(v), t, 0, 8))
show(integral(v, t, 0, 5) + -integral(v, t, 5, 7) + integral(v, t, 7, 8))
# Out:
# [t == 7, t == 5]
# 208
# 208

# %%
v(t) = 400 - 20*t
show(integral(v, t, 0, 7))
# Out:
# 2310

# %%
a(t)=-60
v(t)=integral(a, t) + 70
show(integral(v(t), t))
# Out:
# -30*t^2 + 70*t

# %%
C = var('C')
a(t)=94
v(t) = integral(a(t), t) + C
v(t) = v(t, C=solve(v(0)==0, C)[0].rhs())
s(t) = integral(v(t), t) + C
s(t) = s(t, C=solve(s(0)==0, C)[0].rhs())
show(v(t))
show(s(t))

show(integral(abs(v), t, 0, 4))
show(integral(abs(v), t, 0, 174/94).n())
# Out:
# 94*t
# 47*t^2
# 752
# 161.042553191489

# %%
f(x) = 16*cos(x)
g(x) = 16*sin(x)
sol = solve(f(x)==g(x),x)
low = pi/4
#up = sol[1].rhs()
show(low)
#show(up)
show(integral(g(x), x, 0, low) - integral(f(x), x, 0, low) + (integral(f(x), x, low, pi/2) - integral(g(x), x, low, pi/2)))
# Out:
# 1/4*pi
# -32*sqrt(2) + 32

# %%
show(2 * integral(sqrt(x+15), -15, -6) + integral(sqrt(x+15) - x/2, -6, 10).n())
# Out:
# 85.3333333333333

# %%
y = var('y')
show(integral(8-y-((y-2)^2/3), -4, 5))
# Out:
# 81/2

# %%
show(integral(5*cos(x)-5*cos(2*x), 0, 2*pi/3) + integral(5*cos(2*x)-5*cos(x), 2*pi/3, pi))
# Out:
# 15/2*sqrt(3)

# %%
x = var('x')
f(x) = 1458*sqrt(x)
g(x) = 54*x^2
print(solve(f(x)==g(x), x))
print(integral(f(x) - g(x), x, 0, 9))
# Out:
# [
# x == -3*sqrt(3)*x^(1/4),
# x == 3*sqrt(3)*x^(1/4)
# ]
# 13122

# %%
f(x)=5*x
g(x)=5/x
show(integral(f, x, 0 , 1) + integral(g(x), x, 1, 5))
# Out:
# 5*log(5) + 5/2

# %%
f(x)=abs(x-12)
g(x)=x/2
show(integral(g(x) - f(x), x, 8, 24))
# Out:
# 48

# %%
factor = (1/2)*(1/3)
f(x) = 5*sin(5/2)
sum = 

for i in range(1, 6):
