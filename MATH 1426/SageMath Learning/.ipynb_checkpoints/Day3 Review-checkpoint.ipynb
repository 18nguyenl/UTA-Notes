# %%
x = var('x')
plot([sin(x), cos(x)], xmin=-10, xmax=10, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(sqrt(36-x^2), x)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(integral(x*sin(x), x, 0, pi))
# Out:
# pi

# %%
show(integral(21*x*(6-x), x, 6, 2))
# Out:
# -560

# %%
show(integral(2*x + 5, x, 0, 4))
# Out:
# 36

# %%
show(integral(x^2 - 1, x, 0, 9))
# Out:
# 234

# %%
show(integral(x^2 - 9, x, 3, 8))
# Out:
# 350/3

# %%
show(integral(sin(x) + cos(x), x, -pi/4, 7*pi/4))
# Out:
# 0

# %%
show(integral(4*x^2 + 2, x, 0, 1))
# Out:
# 10/3

# %%
show(integral(2*x^2 + 3*x, x, 3, 5))
# Out:
# 268/3

# %%
show(integral(2*x + sqrt(x), x, 0, 4))
# Out:
# 64/3

# %%
show(integral(x^-3 - 23, x, 1/2, 1))
# Out:
# -10

# %%
show(integral((3-x)*(x-6), x, 3, 6))
# Out:
# 9/2

# %%
show(integral(4*sec(x)^2, x, 0, pi/4))
# Out:
# 4

# %%
show(integral(cos(x)-3, x, -pi/2, pi/2))
# Out:
# -3*pi + 2

# %%
t = var('t')
show(integral(5/t, t, 1, 3))
# Out:
# 5*log(3)

# %%
y = var('y')
show(integral(y^(1/3), y, 1, 8))
# Out:
# 45/4

# %%
show((1/2)*integral(e^x, x, 0, ln(4)))
# Out:
# 3/2

# %%
s = var('s')
show(integral((8*s^2-2)/(s^3), s, 1, 7))
# Out:
# 8*log(7) - 48/49

# %%
z = var('z')
show(integral((z^2+4)/z, z, 1, 2))
# Out:
# 4*log(2) + 3/2

# %%
show(integral(x^2 - 30, x, -2, 4))
# Out:
# -156

# %%
show(-integral(sin(x), x, -2*pi/3, 0) + integral(sin(x), x, 0, pi/3))
# Out:
# 2

# %%
show(integral(19*t^2 + t + 5, t, 2, x).diff())
# Out:
# 19*x^2 + x + 5

# %%
t, x = var('t', 'x')
show(integral((t^3 + 3)^(1/2), t, x, 4))
# Out:
# integrate(sqrt(t^3 + 3), t, 4, x)
