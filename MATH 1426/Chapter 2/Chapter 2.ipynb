# %% [markdown]
# Limits
# ===
# ---

# %% [markdown]
# # 2.1 The Idea of Limits

# %% [markdown]
# ## Average Velocity

# %% [markdown]
# $$v_{av}=\frac{s(t_1)-s(t_0)}{t_1-t_0}$$

# %% [markdown]
# Given $s(t)$, the equation for some distance, this is how you calculate the average velocity for any time interval  $[t_0,t_1]$.

# %% [markdown]
# ## Secant Line

# %% [markdown]
# When you calculate the average velocity using these coordinates $(t_0, s(t_0))$ and $(t_1, s(t_1))$ in the $v_{av}$ equation, you get a ***secant line*** which is a line that connects 2 specific points on a graph.
#
# Slope of a secant line, $m_{sec}$ is = to $v_{av}$

# %%
import plotly.graph_objs as go
import plotly
import numpy as np
import IPython.display

plotly.offline.init_notebook_mode(connected=True)


xs1 = np.arange(-10, 10, .1);
ys1 = -(3 * xs1)**2 + 10;

xs2 = np.arange(-10, 10, .1);
ys2 = 2 * xs2 + 5

data=[go.Scatter(x=xs1, y=ys1, name='f(x)'), go.Scatter(x=xs2, y=ys2, name='secant line')]
layout=go.Layout(xaxis={'range':[-8,8], 'autorange': False}, yaxis={'range':[-20,15], 'autorange': False}, title='secant line formed from linear line intersecting 2 points on f(x)')
figure=go.Figure(data=data, layout=layout)

plotly.offline.iplot(figure)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Instantaneous Velocity

# %% [markdown]
# The instantaneous velocity is the velocity of something at a singple point in time. You calculate this by computing multiple average velocities on intervals $[t_0, t_1]$ that get smaller and smaller. As $t_1$ approaches $t_0$, it eventually reaches the **limit**, the instantaneous velocity.

# %% [markdown]
# | Time interval | Average Velocity |
# | ---| --- |
# | [1,2] | 48 ft/s |
# | [1,1.5] | 56 ft/s |
# | [1,1.1] | 62.4 ft/s |
# | [1,1.01] | 63.84 ft/s |
# | [1,1.001] | 63.984 ft/s |
# | [1, 1.001] | 63.9984 ft/s |

# %% [markdown]
# Note how in this graph, as the intervals get smaller, it seems to approach to 64 ft/s. Considering that there are multiple values that are close to 64 ft/s, it's reasonable to assume that this is the instantaneous velocity.
#
# $$v_{inst}=\lim_{t\rightarrow t_0}v_{av}=\lim_{t\rightarrow t_0}\frac{s(t_1)-s(t_0)}{t-t_0}$$

# %% [markdown]
# ## Tangent Line

# %% [markdown]
# Following the example where $t_1$ approaches $t_0$, the secant line approaches the ***tangent line***. The secant line becomes a tangent line when the secant line touches 1 single point on the function. Consequently, the $m_{sec}$ is = to the $m_{tan}$.
#
# Slope of a tangent line = $m_{tan}$ = $v_{inst}$

# %%
import plotly.graph_objs as go
import plotly
import numpy as np
import IPython.display
import math

plotly.offline.init_notebook_mode(connected=True)


xs1 = np.arange(-10, 10, .01)
ys1 = -(3 * xs1)**2 + 10

xs2 = np.arange(-10, 10, .01)
ys2 = -2 * xs2 -1


data = [go.Scatter(), go.Scatter(x=xs2, y=ys2, name='secant line'), go.Scatter(x=xs1, y=ys1, name='f(x)', line={'width': 3}), ]
layout = go.Layout(
    xaxis = { 
        'range': [-8,8], 
        'autorange': False}, 
    yaxis = {
        'range': [-20,15], 
        'autorange': False}, 
    title ='tangent line forming',
    updatemenus = [{
        'type': 'buttons',
        'buttons': [
        {
            'label': 'Play',
            'method': 'animate',
            'args': [None]
        }
        ]
    }]
)

xI1 = -1
xI2 = 11/9
yI1 = 1
yI2 = -31/9

frames = [
    {
        'data': [{
            'x': [xI1, xI2],
            'y': [yI1, yI2],
            'mode': 'markers',
            'marker': {
                'color': 'red',
                'size': 10
            } ,
            'name': 'intersection points'
        },
        {
            'x': xs2,
            'y': ys2,
            'name': 'secant line'
        }]
    },
    {
        'data': [{
            'x': [xI1, xI2],
            'y': [yI1, yI2],
            'mode': 'markers',
            'marker': {
                'color': 'red',
                'size': 10
            } ,
            'name': 'intersection points'
        },
        {
            'x': xs2,
            'y': ys2 + 4,
            'name': 'secant line'
        }
        ]
    },
    {
        'data': [{
            'x': [xI1, xI2],
            'y': [yI1, yI2],
            'mode': 'markers',
            'marker': {
                'color': 'red',
                'size': 10
            } ,
            'name': 'intersection points'
        },
        {
            'x': xs2,
            'y': ys2 + 6,
            'name': 'secant line'
        }
        ]
    },
    {
        'data': [{
            'x': [.1],
            'y': [9.9],
            'mode': 'markers',
            'marker': {
                'color': 'red',
                'size': 10
            } ,
            'name': 'intersection points'
        },
        {
            'x': xs2,
            'y': ys2 + 11.1,
            'name': 'secant line'
        }
        ]
    }
]

figure=go.Figure(data=data, layout=layout, frames=frames)

plotly.offline.iplot(figure)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # 2.2 Definitions of Limits

# %% [markdown]
# > Say that there's a function $f$ that's defined for all $x$'s near $a$ where $a$ may or may not exist. If $f(x)$ is close to $L$ for all $x$ decently close (but not equal) to $a$, we write
# > $$\lim_{x\rightarrow a}f(x)=L$$
# > and say the limit of $f(x)$ as $x$ approaches $a$ equals $L$

# %% [markdown]
# Informally, we'll say that $\lim_{x\rightarrow a}f(x)=L$ if $f(x)$ gets closer and closer to $L$ as $x$ gets closer and closer to $a$ from both sides. The values of $\lim_{x\rightarrow a}f(x)=L$ rely on the values of $f$ near $a$, but that doesn't mean it relies on the actual $f(a)$. Meaning sometimes $\lim_{x\rightarrow a}f(x)=L$ could equal $f(a)$ or be different (sometimes $f(a)$ may not even exist)

# %% [markdown]
# ## One-Sided Limits

# %% [markdown]
# The limit $\lim_{x\rightarrow a}f(x)=L$ is referred as a *two-sided* limit because $f(x)$ approaches $L$ as $x$ approaches $a$ for values $x$ is greater and less than a.

# %% [markdown]
# ### Right-Sided Limits

# %% [markdown]
# > Assuming $f$ is defined for all $x$ near $a$ where $x>a$. If $f(x)$ approaches $L$ close enough where the values are similar like in the table when $x>a$, we write
# > $$\lim_{x\rightarrow a^+}f(x)=L$$
# > and say the limit of $f(x)$ as $x$ approaches $a$ from the right equals $L$.

# %% [markdown]
# ### Left-Sided Limits

# %% [markdown]
# > Assuming $f$ is defined for all $x$ near $a$ where $x<a$. If $f(x)$ approaches $L$ close enough where the values are similar like in the table when $x<a$, we write
# > $$\lim_{x\rightarrow a^-}f(x)=L$$
# > and say the limit of $f(x)$ as $x$ approaches $a$ from the right equals $L$.

# %% [markdown]
# ## Relationship Between One-Sided and Two-Sided Limits

# %% [markdown]
# #### Therem 2.1 Relationship Between ONe-Sided and Two-Sided Limits
# > Say that there's a function $f$ that's defined for all $x$'s near $a$ where $a$ may or may not exist. Then $\lim_{x\rightarrow a}f(x)=L$ if and only if $\lim_{x\rightarrow a^+}f(x)=L$ and $\lim_{x\rightarrow a^-}f(x)=L$
# > $$\lim_{x\rightarrow a^-}f(x)=\lim_{x\rightarrow a^+}f(x)=\lim_{x\rightarrow a}f(x)=L$$

# %% [markdown]
# # 2.3 Techniques for Computing Limits
# The methods we used before were estimations and therefore sometimes incorrect. In this section, we're going to learn precies methods for calculating limits.

# %% [markdown]
# ## Limits of Linear Functions

# %% [markdown]
# Linear functions follow the form $y=mx+b$ and because it's a straight line that goes infinitely (meaning all points exist, no holes, no weird stuff), the limit for $L$ can be found by plugging $a$ into $f(x)$.
# $$\lim_{x\rightarrow a}f(x)=f(a)$$

# %% [markdown]
# #### Theorem 2.2 Limits of Linear Functions
# >Let $a$,$b$, and $m$ be $\mathbb{R}$. For linear functions $f(x)=mx+b$
# > $$\lim_{x\rightarrow a}f(x)=f(a) = ma + b$$

# %% [markdown]
# ## Limit Laws
# Think of these as "tricks" you can use when working with limits

# %% [markdown]
# #### Theorem 2.3 Limit Laws
# > Assume $\displaystyle\lim{x\rightarrow a}f(x)$ and $\displaystyle\lim{x\rightarrow a}g(x)$ exist, the following properties hold where $c$ is a real number, and $n>0$ is an $\mathbb{z}$ (integer)
# > 1. **Sum** $\displaystyle{\lim_{x\rightarrow a}(f(x)+g(x)=\lim_{x\rightarrow a}f(x)+\lim_{x\rightarrow a}g(x)}$
# > 2. **Differene** $\displaystyle{\lim_{x\rightarrow a}(f(x)-g(x))=\lim_{x\rightarrow a}f(x)-\lim_{x\rightarrow a}g(x)}$
# > 3. **Constant multiple** $\displaystyle{\lim_{x\rightarrow a}(cf(x))=c\lim_{x\rightarrow a}f(x)}$
# > 4. **Product** $\displaystyle{\lim_{x\rightarrow a}(f(x)g(x))=\left(\lim_{x\rightarrow a}f(x)\right)\left(\lim_{x\rightarrow a}g(x)\right)}$
# > 5. **Quotient** $\displaystyle{\lim_{x\rightarrow a}\left(\frac{f(x)}{g(x)}\right)=\frac{\displaystyle\lim_{x\rightarrow a}f(x)}{\displaystyle\lim_{x\rightarrow a}g(x)}}$
# > 6. **Power** $\displaystyle{\lim_{x\rightarrow a}(f(x))^n=\left(\lim_{x\rightarrow a}f(x)\right)^n}$
# > 7. **Root** $\displaystyle{\lim_{x\rightarrow a}(f(x))^{1/n}=\left(\lim_{x\rightarrow a}f(x)\right)^{1/n}}$, provided $f(x)>0$, for $x$ near $a$, if $n$ is even

# %% [markdown]
# ## Limits of Polynomial and Rational Functions
# Similar to limits of linear functions, polynomials also extend infinitely and exist everywhere. Meaning as $x$ approaches $a$ anywhere, there will be a value. Like linear functions, we can figure this value out by plug n' chug.

# %% [markdown]
# #### Theorem 2.4 Limits of Polynomial and Rational Functions
# > Assume $p$ and $q$ are polynomials and $a$ is a constant.
# >
# > a. **Polynomial functions:** $\displaystyle\lim_{x\rightarrow a}p(x)=p(a)$
# >
# > b. **Rational functions:** $\displaystyle\lim_{x\rightarrow a}\frac{p(x)}{q(x)}=\frac{p(a)}{q(a)}$, provided $q(a)\neq0$

# %% [markdown]
# ## Other Techniques
# While substituting in $a$ into $f(x)$ for many limits may be effective, there are some cases where $f(a)$ doesn't exist because of a hole or discontinuity. One way we solve this is to replace it with an equivalent limit that *can* be evaluated with substitution.

# %% [markdown]
# ### Methods
# a. **Factor and cancel**
# Sometimes fractions will have denominators that will result in zero once you plug and chug, however if you factor, the problem will be gone.
#
# #### Example
#
# $$\frac{x^2-6x+8}{x^2-4}$$
#
# When $a$ equals 2, this might seem to not work but...
#
# $$\frac{(x-2)(x-4)}{(x-2)(x+2)}=\frac{x-4}{x+2}$$
#
# Suddenly you can cancel and plug $a$ in and solve!
#
# b. **Use conjugates**
# Similar to the "divide-by-zero" situation above, you can also use the *algebraic conjugate* (especially with roots) to factor and cancel out terms and solve for the limit.
#
# #### Example
#
# $\begin{align*}
# \frac{\sqrt{x}-1}{x-1} \\
# & = \frac{(\sqrt{x}-1)(\sqrt{x}+1)}{(x-1)(\sqrt{x}+1} \\
# & = \frac{1}{\sqrt{x}+1} \\
# \end{align*}$

# %% [markdown]
# ## An Important Limit
# Despite the techniques we learnt before, there's some situations where these don't work. One example is when we have to determine the slope of a line tangent to graph of an *exponential function*

# %% [markdown]
# #### Solution
# Like how we estimated tangent lines before, we can use the slopes of secant lines. First, we look for the point we'd like to approach. Second, we build a table with calculations from both the left and right side of the point to build an approximation to where the limit is headed. Finally, after some verifying, that's our answer.

# %% [markdown]
# ## The Squeeze Theorem

# %% [markdown]
# So say there's a function $f$ and $h$ that have the same limit $L$ at $a$, and that there's a function $g$ trapped between $f$ and $h$, this theorem says that $g$ must have the limit $L$ at $a$ too.
#
# ![Figure 2.21](Figure 2.21.png)

# %% [markdown]
# #### Theorem 2.5 The Squeeze Theorem
# Assume the functions $f$, $g$, and $h$ satisfy $f(x)\leq g(x)\leq h(x)$ for all values of $x$ near $a$, except possibly at $a$. If $\displaystyle{\lim_{x\rightarrow a}f(x)=\lim_{x\rightarrow a}h(x)=L}$ , then $\displaystyle\lim_{x\rightarrow a}g(x)=L$

# %% [markdown]
# ## Trigonometric Limits
# Squeeze theorem is used a lot in establishing the properties of trig functions.

# %% [markdown]
# #### Example

# %% [markdown]
# # 2.4 Infinite Limits
# *Infinite limits* occur when function valuues go on forever. There isn't a point to "approach". There's another type of limit called a *limit at infinity*, which occurs when the independent variable $x$ increases or decreases without bound.

# %% [markdown]
# ## Limits at Infinity
# The *dependent variable* appraoches some finite number as the *independent variable* becomes unknowingly big. In other words, $x\rightarrow a$ where $a$ is something $^+_-\infty$. This means that the graph will go infinitely on some part as it approaches some point. Think vertical or horizontal asymptotes.

# %% [markdown]
# ![Figure 2.23](Figure 2.23.png)

# %% [markdown]
# ## Finding Infinite Limits Analytically
# You can find infinite limits considering this property: the fraction $a/b$ grows really big (infinite) if $b$ approaches 0 while $a$ remains nonzero and realatively constant.
# ### Example I
# $$\lim_{x\rightarrow0^+}\frac{5+x}{x}$$
# Plug in the zero and we see that the numerator equals (approaches 5) while the denominator is positive and approaches 0. Therefore, we can say this equals $\infty$.
# The proof for this is below.
# ![Table 2.8](Table 2.8.png)
# ### Example II
# $$\lim_{x\rightarrow3^+}\frac{2-5x}{x-3}$$
# Plug in $a$ accordingly (so if $a$ approaches from the left of something, plug in something slightly less and vice versa for approaching right) and the numerator approaches -13 while the denominator approaches 0. Since the top is negative and the bottom is positive, the result is $-\infty$.

# %% [markdown]
# ## Finding the Location of Vertical Asymptotes
# It's easier to explain this using an example like so
# $$f(x)=\frac{x^2-4x+3}{x^2-1}$$
# 1. First we factor and cancel out terms to make it become this:
# $$f(x)=\frac{x-3}{x+1}$$
# 2. Next set the denominator factors to equal 0 (you can't divide by 0 so a vertical asymptote might be there
# $$\begin{align*}
# x+1 & =0 \\
# x & =-1
# \end{align*}$$
# 3. Here $x=-1$ is what we think might be the vertical asymptote so we'll test the limits on both sides if they're oppositely infinite (1 is positvely infinite and the other is negatively infinit)
# $$\lim_{x\rightarrow-1^+}f(x)=-\infty \\
# \lim_{x\rightarrow-1^-}f(x)=\infty$$
# 4. If you think abou this graphically like the picture below, you'll realize that there is a vertical asymptote at $x=-1$. There is also a hole determined from the original function.
# ![Figure 2.28b](Figure 2.28b.png)

# %% [markdown]
# ## Infinite Limits
# An example of an *infinite limit* is $\displaystyle\lim_{x\rightarrow a}f(x)=\infty$ meaning $f(x)$ grows arbitrarily large as $x$ approaches $a$. In other words, the *dependent variable* ($y$) becomes unknowingly big as the *independent variable* ($x$) appraoches a some finite number.

# %% [markdown]
# #### Definition | **Infinite Limits**
# Assume $f$ is defined for all $x$ near $a$. If $f(x)$ grows arbitrarily large for all $x$ sufficiently close (but not equal) to $a$, we write
#
# $$\lim_{x\rightarrow a}f(x)=\infty$$
#
# and say the limit of $f(x$ as $x$ approaches $a$ is infinity.
#
#
#
# If $f(x)$ is negative and grows arbitrarily large in magnitude for all $x$ sufficiently close (but not equal) to $A$, we write
#
# $$\lim_{x\rightarrow a}f(x)=-\infty$$
#
# and say the limit of $f(x)$ as $x$ approaches $a$ is negative infinity. *In both cases, the limit does not exist*

# %% [markdown]
# #### Definition | **One-Sided Infinite Limits**
# Suppose $f$ is defined for all $x$ near $a$ with $x>a$. If $f(x)$ becomes arbitrarily large for all $x$ sufficiently close to $a$ with $x>a$, we write $\displaystyle\lim_{x\rightarrow a^+}f(x)=\infty$ (**Figure a.**) The one-sided infinite limits $\displaystyle\lim_{x\rightarrow a^-}f(x)=-\infty$ (**Figure b.**), $\displaystyle\lim_{x\rightarrow a^-}f(x)=\infty$ (**Figure c.**), and $\displaystyle\lim_{x\rightarrow a^-}f(x)=-\infty$ (**Figure d.**) are definied analogously.
#
# ![Figure 2.26](Figure 2.26.png)

# %% [markdown]
# Definition | **Vertical Asymptote**
# All the lines, $x=a$ depicted in the figure above is called a *vertical asymptote*. It's a vertical line that's approached by the graph of $f$ as $x$ approaches $a$.
# If $\displaystyle{\lim_{x\rightarrow a}f(x)=\pm\infty, \lim_{x\rightarrow a^+}f(x)=\pm\infty}$, or $\displaystyle\lim_{x\rightarrow a^-}f(x)=\pm\infty$, the line $x=a$ is called a **vertical asymptote** of $f$

# %% [markdown]
# # 2.5 Limits at Infinity
# This occurs when independent variable becomes really unknowingly big. Because of this, limits at infinity determine the *end behavior* of a function. Examples for uses for this is to determine whether a system reaches a steady state as time increases.

# %% [markdown]
# ## Limits at Infinity and Horizontal Asymptotes
# As $x\rightarrow\pm\infty$, the function can approach to some horizontal line (similar to vertical asymptote) but never touch it. This is called the *horizontal asymptote*.

# %% [markdown]
# #### Defintion | **Limits at Infinity and Horizontal Asymptotes**
# If $f(x)$ becomes arbitrarily close to a finite number $L$ for all sufficiently large $\pm x$, then we write
#
# $$\lim_{x\rightarrow\pm\infty}f(x)=L$$
#
# In this graph, $y=L$ and $y=M$ are both **horizontal asymptotes**. Notice what $x$ approaches to $a$ and the differences.
#
# ![Figure 2.31](Figure 2.31.png)

# %% [markdown]
# ## Using Limits to find Horizontal Asymptotes
# Plug in the limit at infinity and bam you got it.

# %% [markdown]
# ## Infinite Limits at Infinity
# It's possible to both have an infinite and a limit at infinity or an *infinite limit at infinity*.

# %% [markdown]
# #### Definition | **Infinite Limits at Infinity**
